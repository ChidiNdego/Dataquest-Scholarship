# %% [markdown]
# # PROJECT: Visualizing Earning Based on College Majors

# %% [markdown]
# Project concentrates on exploring data on job outcomes with visualizing and extracting insightful information about the data.

# %%
#importing the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#reading the data into pandas library
recent_grads = pd.read_csv('recent-grads.csv')

# %% [markdown]
# ### Description of data column names
# * Rank - Rank by median earnings (the dataset is ordered by this column).
# * Major_code - Major code.
# * Major - Major description.
# * Major_category - Category of major.
# * Total - Total number of people with major.
# * Sample_size - Sample size (unweighted) of full-time.
# * Men - Male graduates.
# * Women - Female graduates.
# * ShareWomen - Women as share of total.
# * Employed - Number employed.
# * Median - Median salary of full-time, year-round workers.
# * Low_wage_jobs - Number in low-wage service jobs.
# * Full_time - Number employed 35 hours or more.
# * Part_time - Number employed less than 35 hours.

# %%
#view of the first row in the dataset
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
#an overview of the dataset
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
#statistical description of the dataset
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
#number of rows in our dataframe
recent_grads.shape[0]
# Out:
# 173

# %%
#scatter plot of sample size of full-time year round and median earnings of full-time year round
recent_grads.plot(x='Sample_size',y='Median',kind='scatter')

# %%
#scatter plot of sample size and unemployment rate
recent_grads.plot(x='Sample_size',y='Unemployment_rate',kind='scatter')

# %%
#scatter plot of full time employee (35 hours or more) and median earnings of full-time
recent_grads.plot(x='Full_time',y='Median',kind='scatter')

# %%
#scatter plot of women (as share of total) and unemployment rate
recent_grads.plot(x='ShareWomen',y='Unemployment_rate',kind='scatter')

# %%
#scatter plot of male graduates and median earnings
recent_grads.plot(x='Men',y='Median',kind='scatter')

# %%
#scatter plot of female grauates and median earnings
recent_grads.plot(x='Women',y='Median',kind='scatter')

# %%
#histogram of sample size of full-time
recent_grads['Sample_size'].hist(bins=50,range=(0,3000))

# %%
#histogram of median earnings
recent_grads['Median'].hist(bins=50,range=(20000,80000))

# %%
#histogram of employed
recent_grads['Employed'].hist(bins=50,range=(0,200000))

# %%
#histogram of full time employee (35 hours or more)
recent_grads['Full_time'].hist(bins=50,range=(0,180000))

# %%
#histogram of women (as share of total)
recent_grads['ShareWomen'].hist(bins=50)

# %%
#histogram of unemployment rate
recent_grads['Unemployment_rate'].hist(bins=50)

# %%
#histogram of male graduates
recent_grads['Men'].hist(bins=50,range=(0,120000))

# %%
#histogram of female graduates
recent_grads['Women'].hist(bins=50,range=(0,200000))

# %%
cols = ["Sample_size", "Median", "Employed", "Full_time", "ShareWomen", "Unemployment_rate", "Men", "Women"]

fig = plt.figure(figsize=(5,12))
for r in range(0,4):
    ax = fig.add_subplot(4,1,r+1)
    ax = recent_grads[cols[r]].plot(kind="hist")

# %%
cols = ["Sample_size", "Median", "Employed", "Full_time", "ShareWomen", "Unemployment_rate", "Men", "Women"]

fig = plt.figure(figsize=(5,12))
for r in range(4,8):
    ax = fig.add_subplot(4,1,r-3)
    ax = recent_grads[cols[r]].plot(kind="hist")

# %%
from pandas.plotting import scatter_matrix

# %%
#scatter and histogram plot of sample size and median earnings
scatter_matrix(recent_grads[['Sample_size','Median']],figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000239F793DEB8>,
# ...
#       dtype=object)

# %%
#scatter and histogram plot of sample size, median earnings, and unemployment rate
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']],figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000239F7956278>,
# ...
#       dtype=object)

# %%
#bar plot of the first five rows showing count of female graduates and their majors
recent_grads[:5].plot.bar(x='Major', y='Women')

# %%
recent_grads[:10]['ShareWomen'].plot(kind='bar')

# %%
recent_grads[-10:]['ShareWomen'].plot(kind='bar')

# %%
recent_grads[:10]['Unemployment_rate'].plot(kind='bar')

# %%
recent_grads[-10:]['Unemployment_rate'].plot(kind='bar')

# %%
recent_grads['Major_category'].value_counts()
# Out:
# Engineering                            29
# Education                              16
# Humanities & Liberal Arts              15
# Biology & Life Science                 14
# Business                               13
# Health                                 12
# Computers & Mathematics                11
# Physical Sciences                      10
# Agriculture & Natural Resources        10
# Psychology & Social Work                9
# Social Science                          9
# Arts                                    8
# Industrial Arts & Consumer Services     7
# Law & Public Policy                     5
# Communications & Journalism             4
# Interdisciplinary                       1
# Name: Major_category, dtype: int64

# %%
recent_grads.groupby('Major_category')['Men','Women'].sum().plot(kind='bar',figsize=(12,12))

# %% [markdown]
# Clearly, male graduates largely dominate their female counterparts in Computers & Mathematics and Engineering categories. The females, on the other hand, dominate in Health, Education, Communications & Journalism, Humanities & Liberal Arts, and Psychology & Social Work categories. All other categories have considerably close number of male and female graduates.

# %%
fig = plt.figure(figsize=(15,15))
ax1 = fig.add_subplot(2,1,1)
ax1.boxplot(recent_grads['Unemployment_rate'].values)
ax2 = fig.add_subplot(2,1,2)
ax2.boxplot(recent_grads['Median'].values)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x239f8445780>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x239f8445cc0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x239f8445160>],
#  'medians': [<matplotlib.lines.Line2D at 0x239f844d940>],
#  'fliers': [<matplotlib.lines.Line2D at 0x239f844dda0>],
#  'means': []}

# %%
recent_grads.plot.hexbin(y='Sample_size',x='Median',gridsize=(50,50),figsize=(20,20))
